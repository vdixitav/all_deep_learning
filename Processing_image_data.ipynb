# %% [markdown]
# TOPICS
#
# 1) READING AN IMAGE FILE AND CONVERTING IT TO NUMPY ARRAY
#
# 2) RESIZING IMAGE
#
# 3)RGB TO GARYSCALE CONVERSION

# %%
# !wget "https://up.yimg.com/ib/th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106"
# Out:
# --2024-10-18 17:23:28--  https://up.yimg.com/ib/th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106
# Resolving up.yimg.com (up.yimg.com)... 74.6.160.106, 74.6.160.107, 69.147.80.15, ...
# Connecting to up.yimg.com (up.yimg.com)|74.6.160.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8549 (8.3K) [image/jpeg]
# Saving to: ‘th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106’
#
# th?id=OIP.BK8STvfoG 100%[===================>]   8.35K  --.-KB/s    in 0s
#
# 2024-10-18 17:23:28 (53.4 MB/s) - ‘th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106’ saved [8549/8549]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread("/content/th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (106, 142, 3)

# %%
print(img)
# Out:
# [[[90 88 47]
#   [86 87 45]
#   [84 87 42]
#   ...
#   [30 48  0]
#   [43 57  8]
#   [80 92 44]]
#
#  [[83 79 41]
#   [82 80 41]
#   [82 83 39]
#   ...
#   [32 51  6]
#   [40 55 14]
#   [75 87 47]]
#
#  [[71 65 33]
#   [73 69 32]
#   [76 75 31]
#   ...
#   [31 50 20]
#   [31 47 20]
#   [55 69 43]]
#
#  ...
#
#  [[54 30 28]
#   [46 22 18]
#   [59 35 33]
#   ...
#   [52 28 28]
#   [55 34 33]
#   [41 20 19]]
#
#  [[46 22 18]
#   [52 29 23]
#   [53 29 25]
#   ...
#   [43 19 17]
#   [40 19 16]
#   [42 21 18]]
#
#  [[57 34 28]
#   [53 30 24]
#   [55 32 26]
#   ...
#   [42 18 16]
#   [37 16 13]
#   [39 18 15]]]

# %%
# displaying image from numpy array

img_plot=plt.imshow(img)
plt.show()

# %%
# resizing image using pillow

# %%
from PIL import Image

# %%
img=Image.open("/content/th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106")
img_resized=img.resize((200,200))

# %%
print(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7C0BCE76FE20>

# %%
img_resized.save("/content/th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106.jpg")

# %%
img_rs=mpimg.imread('/content/th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106.jpg')

# %%
img_plot=plt.imshow(img_rs)
plt.show()

# %%
# convert rgb into grayscale

# %%
import cv2

# %%
img=cv2.imread("/content/th?id=OIP.BK8STvfoGAkPFIe0cTCMxAHaFj&pid=Api&rs=1&c=1&qlt=95&w=142&h=106.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
gray_scale_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
print(gray_scale_image)
# Out:
# [[82 82 82 ... 42 63 83]
#  [80 80 80 ... 43 63 83]
#  [76 76 77 ... 44 62 81]
#  ...
#  [34 34 35 ... 26 26 27]
#  [38 37 38 ... 23 23 23]
#  [41 40 39 ... 24 22 21]]

# %%
type(gray_scale_image)
# Out:
# numpy.ndarray

# %%
gray_scale_image.shape
# Out:
# (200, 200)

# %%
#cv2.imshow() not allow in colab

from google.colab.patches import cv2_imshow
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=200x200>
